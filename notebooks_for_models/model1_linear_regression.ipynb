# %% [markdown]
# ## Purpose: Try different models-- Part1.
# ### Linear Regression

# %%
# import dependencies.
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### STEP1: Read in dataset.  Remove data from 2016-2019.
# - data from 2016-2018 will be used to bs test the model.
# - data from 2019 will be used to predict the winners of the 2019 WS.

# %%
# read in the data.
team_data = pd.read_csv("../Resources/clean_data.csv")
del team_data["Unnamed: 0"]
team_data.head()
# Out:
#                    team  year     A   DP   E   G2  GS2     INN  PB    PO  \
# 0   St. Louis Cardinals  2019  1033  114  43  104  936  8313.0   3  2771
# 1  Arizona Diamondbacks  2019  1010   83  45  105  945  8538.0   2  2846
# 2    Kansas City Royals  2019   990  105  45  106  954  8421.0   6  2807
# 3        Houston Astros  2019   875   54  50  106  954  8589.0   6  2863
# 4        Tampa Bay Rays  2019   975   92  53  107  963  8760.0  11  2920
#
#     ...      R1  SHO   SO1  SV   TBF   W  WHIP  WP   WPCT  winners
# 0   ...     456    4   895  33  3896  56  1.29  21  0.538        0
# 1   ...     472    7   925  24  4001  53  1.28  35  0.505        0
# 2   ...     543    5   816  24  4125  39  1.46  34  0.368        0
# 3   ...     432    7  1074  27  3929  67  1.14  31  0.632        0
# 4   ...     409    6  1037  26  3985  59  1.16  40  0.551        0
#
# [5 rows x 55 columns]

# %%
# remove data from 2016 through 2019.
team_data_new = team_data.loc[team_data["year"] < 2016]
team_data_new.head()
# Out:
#                      team  year     A   DP   E   G2   GS2      INN  PB    PO  \
# 120  San Francisco Giants  2015  1639  136  72  162  1458  13143.0   6  4381
# 121  Washington Nationals  2015  1425  142  73  162  1458  13137.0  17  4379
# 122        Houston Astros  2015  1599  135  77  162  1458  13212.0  18  4404
# 123        Detroit Tigers  2015  1537  148  75  161  1449  12852.0   5  4284
# 124        Boston Red Sox  2015  1427  139  75  162  1458  12957.0  37  4319
#
#       ...      R1  SHO   SO1  SV   TBF   W  WHIP  WP   WPCT  winners
# 120   ...     631   11  1309  43  6048  87  1.21  40  0.537        0
# 121   ...     612   12  1476  46  6036  95  1.19  47  0.586        0
# 122   ...     701    8  1396  44  6180  84  1.29  98  0.519        0
# 123   ...     721    8  1232  47  6048  86  1.32  44  0.534        0
# 124   ...     694    5  1362  43  6073  93  1.27  52  0.574        0
#
# [5 rows x 55 columns]

# %%
# models require numbers! Drop team and year columns.
target = team_data_new["winners"]
features = team_data_new.drop({"team", "year", "winners"}, axis=1)
print (target.shape)
print (features.shape)
# Out:
# (2344,)
# (2344, 52)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=42)

# %% [markdown]
# #### STEP2: Try Linear Regression.

# %%
# fit the model.
model = LinearRegression()
model.fit(X_train, y_train)

# predict.
predicted = model.predict(X_test)

# evaluate the model.
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print (f"MSE: {mse}")
print (f"R-squared: {r2}")
# Out:
# MSE: 0.05103749906253885
# R-squared: 0.03961460748098067

# %% [markdown]
# The linear model doesn't work.  The R-squared value is absolutely abysmal.  I could pick a one at random and do a better job!

# %% [markdown]
# #### STEP5: Try Grid Search.

# %%
# set up svc model.
model = SVC(kernel="linear", probability=True)

# create gridsearch estimator.
param_grid = {"C": [1, 5, 10],
             "gamma": [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# fit the model.
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... C=1, gamma=0.0001, score=0.9557069846678024, total=   1.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV] ...... C=1, gamma=0.0001, score=0.9556313993174061, total=   1.5s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.9s remaining:    0.0s
# [CV] ...... C=1, gamma=0.0001, score=0.9572649572649573, total=   1.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.9557069846678024, total=   1.3s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.9556313993174061, total=   1.5s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.9572649572649573, total=   1.6s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.9557069846678024, total=   1.4s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.9556313993174061, total=   1.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.9572649572649573, total=   1.5s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.9557069846678024, total=   2.6s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.9556313993174061, total=   2.7s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.9572649572649573, total=   2.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.9557069846678024, total=   2.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.9556313993174061, total=   2.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.9572649572649573, total=   2.6s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.9557069846678024, total=   2.4s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.9556313993174061, total=   2.5s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.9572649572649573, total=   2.6s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.9557069846678024, total=   2.9s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.9556313993174061, total=   3.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.9572649572649573, total=   3.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.9557069846678024, total=   3.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.9556313993174061, total=   3.4s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.9572649572649573, total=   3.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.9557069846678024, total=   3.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.9556313993174061, total=   3.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.9572649572649573, total=   3.1s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.1min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
print (grid.best_params_)
print (grid.best_score_)
print (grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.0001}
# 0.9562002275312855
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
grid = grid.best_estimator_
predictions = grid.predict(X_test_scaled)
print (classification_report(y_test, predictions, target_names=["0", "1"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       553
#            1       0.00      0.00      0.00        33
#
#    micro avg       0.94      0.94      0.94       586
#    macro avg       0.47      0.50      0.49       586
# weighted avg       0.89      0.94      0.92       586
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# grab the 2018 data.
team_data_2018 = team_data.loc[team_data["year"] == 2018].reset_index()

# set features (no team, year, winners).
# set target (winners).
features_2018 = team_data_2018.drop({"team", "year", "winners"}, axis=1).drop({"index"}, axis=1)
features_2018 = X_scaler.transform(features_2018)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
# fit the model.
probabilities = grid.predict_proba(features_2018)[:, 1]

# convert predictions to datafram.e
WS_predictions = pd.DataFrame(probabilities).sort_values(0, ascending=False)

WS_predictions['Probability'] = WS_predictions[0]

# Print 50 highest probability HoF inductees from still eligible players
for i, row in WS_predictions.head(50).iterrows():
   prob = ' '.join(('WS Probability =', str(row['Probability'])))
   print('')
   print(prob)
   print(team_data_2018.iloc[i,1:27]["team"])
# Out:
# WS Probability = 0.045111803230076
# Los Angeles Dodgers
#
# WS Probability = 0.0450749360117753
# Houston Astros
#
# WS Probability = 0.045025262092605066
# Atlanta Braves
#
# WS Probability = 0.04492917338428611
# Boston Red Sox
#
# WS Probability = 0.04489767751368868
# New York Yankees
#
# WS Probability = 0.04484348696934137
# Chicago Cubs
#
# WS Probability = 0.044717444535049715
# Minnesota Twins
#
# WS Probability = 0.04471278743004486
# Milwaukee Brewers
#
# WS Probability = 0.04466215911570443
# Los Angeles Angels
#
# WS Probability = 0.04465666456839028
# Washington Nationals
#
# WS Probability = 0.044591492476011955
# Arizona Diamondbacks
#
# WS Probability = 0.0444710511531071
# Tampa Bay Rays
#
# WS Probability = 0.04446734367395021
# Cleveland Indians
#
# WS Probability = 0.04445790564195987
# New York Mets
#
# WS Probability = 0.04440410411790097
# Pittsburgh Pirates
#
# WS Probability = 0.04434200318359911
# St. Louis Cardinals
#
# WS Probability = 0.04432049322905022
# Seattle Mariners
#
# WS Probability = 0.04431980463865152
# Philadelphia Phillies
#
# WS Probability = 0.044309420817771006
# Oakland Athletics
#
# WS Probability = 0.04425918396151201
# Texas Rangers
#
# WS Probability = 0.044138541914593286
# Cincinnati Reds
#
# WS Probability = 0.04413467483413916
# Colorado Rockies
#
# WS Probability = 0.0440530403488659
# Kansas City Royals
#
# WS Probability = 0.04390859435021941
# San Diego Padres
#
# WS Probability = 0.04380712935212636
# Chicago White Sox
#
# WS Probability = 0.04362889944031767
# San Francisco Giants
#
# WS Probability = 0.043578917856453854
# Toronto Blue Jays
#
# WS Probability = 0.043517993874019625
# Baltimore Orioles
#
# WS Probability = 0.043512796542335364
# Miami Marlins
#
# WS Probability = 0.04315627893122138
# Detroit Tigers

# %% [markdown]
# Nope.

# %%
# grab the 2017 data.
team_data_2017 = team_data.loc[team_data["year"] == 2017].reset_index()

# set features (no team, year, winners).
# set target (winners).
features_2017 = team_data_2017.drop({"team", "year", "winners"}, axis=1).drop({"index"}, axis=1)
features_2017 = X_scaler.transform(features_2017)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
# fit the model.
probabilities = grid.predict_proba(features_2017)[:, 1]

# convert predictions to datafram.e
WS_predictions = pd.DataFrame(probabilities).sort_values(0, ascending=False)

WS_predictions['Probability'] = WS_predictions[0]

# Print 50 highest probability HoF inductees from still eligible players
for i, row in WS_predictions.head(50).iterrows():
   prob = ' '.join(('WS Probability =', str(row['Probability'])))
   print('')
   print(prob)
   print(team_data_2017.iloc[i,1:27]["team"])
# Out:
# WS Probability = 0.04551790370305243
# New York Yankees
#
# WS Probability = 0.0454952848466519
# Milwaukee Brewers
#
# WS Probability = 0.0454603586224575
# Atlanta Braves
#
# WS Probability = 0.04544354598777052
# Chicago Cubs
#
# WS Probability = 0.0454327549008477
# St. Louis Cardinals
#
# WS Probability = 0.04541762995956363
# Tampa Bay Rays
#
# WS Probability = 0.04540655058721021
# Cleveland Indians
#
# WS Probability = 0.04539202758507097
# Pittsburgh Pirates
#
# WS Probability = 0.04538370004444116
# Colorado Rockies
#
# WS Probability = 0.045380378004029
# Cincinnati Reds
#
# WS Probability = 0.04535503252443406
# New York Mets
#
# WS Probability = 0.045353810417980915
# Houston Astros
#
# WS Probability = 0.04534840252111887
# Philadelphia Phillies
#
# WS Probability = 0.045347066584589465
# Toronto Blue Jays
#
# WS Probability = 0.04533562856852184
# Arizona Diamondbacks
#
# WS Probability = 0.04530326383191588
# Seattle Mariners
#
# WS Probability = 0.045300963441641355
# Kansas City Royals
#
# WS Probability = 0.0452992643417917
# Detroit Tigers
#
# WS Probability = 0.045297311415821544
# Los Angeles Angels
#
# WS Probability = 0.04529013550593184
# Texas Rangers
#
# WS Probability = 0.04528398916192368
# Minnesota Twins
#
# WS Probability = 0.04526768301371895
# Chicago White Sox
#
# WS Probability = 0.0452652370373309
# Washington Nationals
#
# WS Probability = 0.04526424351662302
# San Francisco Giants
#
# WS Probability = 0.04525755541310071
# Miami Marlins
#
# WS Probability = 0.04525377202315708
# Oakland Athletics
#
# WS Probability = 0.04524086549037409
# San Diego Padres
#
# WS Probability = 0.04523494078897681
# Boston Red Sox
#
# WS Probability = 0.04521373758555692
# Baltimore Orioles
#
# WS Probability = 0.04515080344304217
# Los Angeles Dodgers

# %% [markdown]
# Nope.  This is worse than the previous one.  Maybe there are too many features.  Let's PCA this thing.

# %% [markdown]
# #### STEP6: PCA.

# %%
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=42)

# scale X_train and X_test.
scaler = StandardScaler()

# transform the training and testing data.
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# apply pca on the X components.
pca = PCA(n_components = 2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.fit_transform(X_test_scaled)

explained_variance = pca.explained_variance_ratio_
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
classifier = LogisticRegression(solver="lbfgs", random_state=42) 
classifier.fit(X_train_pca, y_train) 
predictions = classifier.predict(X_test_pca)

# %%
print (classification_report(y_test, predictions, target_names=["0", "1"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       553
#            1       0.00      0.00      0.00        33
#
#    micro avg       0.94      0.94      0.94       586
#    macro avg       0.47      0.50      0.49       586
# weighted avg       0.89      0.94      0.92       586
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# grab the 2018 data.
team_data_2018 = team_data.loc[team_data["year"] == 2018].reset_index()

# set features (no team, year, winners).
# set target (winners).
features_2018 = team_data_2018.drop({"team", "year", "winners"}, axis=1).drop({"index"}, axis=1)
features_2018 = scaler.fit_transform(features_2018)
features_2018 = pca.fit_transform(features_2018)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# fit the model.
probabilities = classifier.predict_proba(features_2018)

# convert predictions to datafram.e
WS_predictions = pd.DataFrame(probabilities[:,1])

# Sort the DataFrame (descending)
WS_predictions = WS_predictions.sort_values(0, ascending=False)

WS_predictions['Probability'] = WS_predictions[0]

# Print 50 highest probability HoF inductees from still eligible players
for i, row in WS_predictions.head(50).iterrows():
   prob = ' '.join(('WS Probability =', str(row['Probability'])))
   print('')
   print(prob)
   print(team_data_2018.iloc[i,1:27]["team"])
# Out:
# WS Probability = 0.09035555848469622
# Cincinnati Reds
#
# WS Probability = 0.08726213645815503
# Cleveland Indians
#
# WS Probability = 0.0747569248671306
# Miami Marlins
#
# WS Probability = 0.07278240658813295
# Los Angeles Dodgers
#
# WS Probability = 0.06114789170583012
# Washington Nationals
#
# WS Probability = 0.06036181368769516
# San Diego Padres
#
# WS Probability = 0.06026986153959294
# St. Louis Cardinals
#
# WS Probability = 0.05841762176744002
# Chicago White Sox
#
# WS Probability = 0.05490991970500289
# Houston Astros
#
# WS Probability = 0.05115205473420071
# New York Yankees
#
# WS Probability = 0.04869697783059115
# Chicago Cubs
#
# WS Probability = 0.04770953978200814
# Detroit Tigers
#
# WS Probability = 0.0457877111644281
# New York Mets
#
# WS Probability = 0.04562240410874296
# Minnesota Twins
#
# WS Probability = 0.04330624781567202
# Tampa Bay Rays
#
# WS Probability = 0.039817307651562446
# San Francisco Giants
#
# WS Probability = 0.038401955417204967
# Philadelphia Phillies
#
# WS Probability = 0.0382985084449339
# Arizona Diamondbacks
#
# WS Probability = 0.03445002271423805
# Oakland Athletics
#
# WS Probability = 0.034350895951406966
# Atlanta Braves
#
# WS Probability = 0.03344253184150308
# Pittsburgh Pirates
#
# WS Probability = 0.030710866159368633
# Milwaukee Brewers
#
# WS Probability = 0.030022529088332094
# Texas Rangers
#
# WS Probability = 0.029161540480006135
# Los Angeles Angels
#
# WS Probability = 0.028326256946986008
# Baltimore Orioles
#
# WS Probability = 0.025250507994030325
# Toronto Blue Jays
#
# WS Probability = 0.025060286083947406
# Kansas City Royals
#
# WS Probability = 0.02331823084363272
# Boston Red Sox
#
# WS Probability = 0.018729490536504224
# Colorado Rockies
#
# WS Probability = 0.015215664919090108
# Seattle Mariners

# %%
# grab the 2017 data.
team_data_2017 = team_data.loc[team_data["year"] == 2017].reset_index()

# set features (no team, year, winners).
# set target (winners).
features_2017 = team_data_2017.drop({"team", "year", "winners"}, axis=1).drop({"index"}, axis=1)
features_2017 = scaler.fit_transform(features_2017)
features_2017 = pca.fit_transform(features_2017)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# fit the model.
probabilities = classifier.predict_proba(features_2017)

# convert predictions to datafram.e
WS_predictions = pd.DataFrame(probabilities[:,1])

# Sort the DataFrame (descending)
WS_predictions = WS_predictions.sort_values(0, ascending=False)

WS_predictions['Probability'] = WS_predictions[0]

# Print 50 highest probability HoF inductees from still eligible players
for i, row in WS_predictions.head(50).iterrows():
   prob = ' '.join(('WS Probability =', str(row['Probability'])))
   print('')
   print(prob)
   print(team_data_2017.iloc[i,1:27]["team"])
# Out:
# WS Probability = 0.08334583135908803
# Pittsburgh Pirates
#
# WS Probability = 0.06892370448408
# Miami Marlins
#
# WS Probability = 0.059441137841465985
# Houston Astros
#
# WS Probability = 0.058251944323909476
# Cleveland Indians
#
# WS Probability = 0.05256772875130675
# Detroit Tigers
#
# WS Probability = 0.05191074112615728
# Minnesota Twins
#
# WS Probability = 0.0509044678642867
# New York Yankees
#
# WS Probability = 0.050431775817083704
# Los Angeles Angels
#
# WS Probability = 0.05002827483292677
# Boston Red Sox
#
# WS Probability = 0.0496906770060075
# Kansas City Royals
#
# WS Probability = 0.04948943800265006
# Toronto Blue Jays
#
# WS Probability = 0.04927404697045466
# Washington Nationals
#
# WS Probability = 0.04789597724912886
# Seattle Mariners
#
# WS Probability = 0.04775645593544893
# New York Mets
#
# WS Probability = 0.047608915751616784
# Baltimore Orioles
#
# WS Probability = 0.04256153670154059
# Oakland Athletics
#
# WS Probability = 0.04220271114102812
# Chicago White Sox
#
# WS Probability = 0.041130583432789934
# Texas Rangers
#
# WS Probability = 0.03955318433136112
# Atlanta Braves
#
# WS Probability = 0.039326944429514524
# Philadelphia Phillies
#
# WS Probability = 0.03853961300679515
# Tampa Bay Rays
#
# WS Probability = 0.03616156179383917
# Cincinnati Reds
#
# WS Probability = 0.035400654442533507
# San Diego Padres
#
# WS Probability = 0.034359862731533096
# St. Louis Cardinals
#
# WS Probability = 0.03346543677003278
# Arizona Diamondbacks
#
# WS Probability = 0.03215012425080334
# San Francisco Giants
#
# WS Probability = 0.020883952602036925
# Milwaukee Brewers
#
# WS Probability = 0.020326536238424217
# Los Angeles Dodgers
#
# WS Probability = 0.01940740740852149
# Colorado Rockies
#
# WS Probability = 0.016046642165604787
# Chicago Cubs

# %%
# grab the 2016 data.
team_data_2016 = team_data.loc[team_data["year"] == 2016].reset_index()

# set features (no team, year, winners).
# set target (winners).
features_2016 = team_data_2016.drop({"team", "year", "winners"}, axis=1).drop({"index"}, axis=1)
features_2016 = scaler.fit_transform(features_2016)
features_2016 = pca.fit_transform(features_2016)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# fit the model.
probabilities = classifier.predict_proba(features_2016)

# convert predictions to datafram.e
WS_predictions = pd.DataFrame(probabilities[:,1])

# Sort the DataFrame (descending)
WS_predictions = WS_predictions.sort_values(0, ascending=False)

WS_predictions['Probability'] = WS_predictions[0]

# Print 50 highest probability HoF inductees from still eligible players
for i, row in WS_predictions.head(50).iterrows():
   prob = ' '.join(('WS Probability =', str(row['Probability'])))
   print('')
   print(prob)
   print(team_data_2016.iloc[i,1:27]["team"])
# Out:
# WS Probability = 0.07518649138549548
# Boston Red Sox
#
# WS Probability = 0.07173895535288484
# Los Angeles Dodgers
#
# WS Probability = 0.06913223259173937
# Los Angeles Angels
#
# WS Probability = 0.0628083102599146
# San Francisco Giants
#
# WS Probability = 0.06095787881986291
# Cleveland Indians
#
# WS Probability = 0.05938123010619937
# Pittsburgh Pirates
#
# WS Probability = 0.05812916659804329
# Tampa Bay Rays
#
# WS Probability = 0.0567781185071319
# Toronto Blue Jays
#
# WS Probability = 0.05649292718003708
# San Diego Padres
#
# WS Probability = 0.050149676502835895
# St. Louis Cardinals
#
# WS Probability = 0.05012894831889737
# Milwaukee Brewers
#
# WS Probability = 0.04375991998036347
# Arizona Diamondbacks
#
# WS Probability = 0.04284524701441389
# Kansas City Royals
#
# WS Probability = 0.04230299886796214
# Washington Nationals
#
# WS Probability = 0.041082393645504936
# Philadelphia Phillies
#
# WS Probability = 0.040559063104420444
# Seattle Mariners
#
# WS Probability = 0.040401080287095964
# New York Yankees
#
# WS Probability = 0.038446263572630916
# Chicago Cubs
#
# WS Probability = 0.03370687985952188
# Minnesota Twins
#
# WS Probability = 0.03280851472492482
# Oakland Athletics
#
# WS Probability = 0.03256148893785172
# Atlanta Braves
#
# WS Probability = 0.03188589982128663
# Texas Rangers
#
# WS Probability = 0.028650021911809494
# Chicago White Sox
#
# WS Probability = 0.02852124951101834
# New York Mets
#
# WS Probability = 0.02848044454109261
# Colorado Rockies
#
# WS Probability = 0.027852496698974306
# Baltimore Orioles
#
# WS Probability = 0.02633125742085485
# Miami Marlins
#
# WS Probability = 0.025407400789864396
# Houston Astros
#
# WS Probability = 0.025115385445729183
# Detroit Tigers
#
# WS Probability = 0.02504006109752067
# Cincinnati Reds

# %% [markdown]
# 2016-2018 checks doesn't work. And this is worse than the straight up logistic regression.  I'm going to end this notebook here and try other models in another notebook.
#
# The reason the logistic models aren't working is because the data is not balanced--there are way more ws losers than there are winners.  Might want to try Kappa .
